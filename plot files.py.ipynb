# %%
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3]
y = [2, 4, 1]

plt.plot(x, y)
plt. show()

# %%
x1 = [1,2,3]
y1 = [2,4,1]

plt.plot(x1, y1)
x2 = [1,2,3]
y2 = [4,1,3]

plt.plot(x2, y2)

plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.
